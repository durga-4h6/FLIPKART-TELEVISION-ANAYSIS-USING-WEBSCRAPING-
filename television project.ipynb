# %%
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import requests
import warnings
warnings.filterwarnings("ignore")

# %%
url="https://www.flipkart.com/search?q=television"

# %%
response=requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
pagecontent=response.text

# %%
soup=BeautifulSoup(pagecontent)

# %%
<div data-id="COMG9VHHF6HVJPP9" style="width: 100%;"><div class="jIjQ8S" data-tkid="en_ID-0s5HWpq_SywYaWcPFRfABFcpIldRNEgNCNtDI4PrAT4BffvSlcEwvwgROmXNrn0WVbdNFF5OvNPBl0Ab1-_UFjCTyOHoHZs-Z5_PS_w0="><a class="k7wcnx" target="_blank" rel="noopener noreferrer" href="/lenovo-ideapad-slim-1-amd-ryzen-5-hexa-core-5500u-8-gb-512-gb-ssd-windows-11-home-15acl6-15alc7-2-thin-light-laptop/p/itm3680fb576eb7b?pid=COMG9VHHF6HVJPP9&amp;lid=LSTCOMG9VHHF6HVJPP9U213LU&amp;marketplace=FLIPKART&amp;q=laptop&amp;store=6bo%2Fb5g&amp;srno=s_1_1&amp;otracker=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&amp;otracker1=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&amp;fm=organic&amp;iid=en_ID-0s5HWpq_SywYaWcPFRfABFcpIldRNEgNCNtDI4PrAT4BffvSlcEwvwgROmXNrn0WVbdNFF5OvNPBl0Ab1-_UFjCTyOHoHZs-Z5_PS_w0%3D&amp;ppt=None&amp;ppn=None&amp;ssid=sl6ljjdi6o0000001767327211808&amp;qH=312f91285e048e09"><div class="T6hTMI" data-tkid="ADVIEW_en_ID-0s5HWpq_SywYaWcPFRfABFcpIldRNEgNCNtDI4PrAT4BffvSlcEwvwgROmXNrn0WVbdNFF5OvNPBl0Ab1-_UFjCTyOHoHZs-Z5_PS_w0="><div class="R7Cntx"><div><div class="lWX0_T" style="height: 200px; width: 200px;"><img loading="eager" class="UCc1lI" alt="Lenovo IdeaPad Slim 1 AMD Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/Windows 11 Home) 15ACL6 | 15ALC7 ..." src="https://rukminim2.flixcart.com/image/312/312/xif0q/computer/m/o/u/-original-imahg5fxhyfzpqwy.jpeg?q=70"></div></div></div><div class="b0bTm6"><div class="FJ7IAS"><span class="ZhHnSZ"><label class="BMOCJ3"><input type="checkbox" class="UXWKAE" readonly=""><div class="ybaCDx"></div></label></span><label class="fU6cHR"><span>Add to Compare</span></label></div></div><div class="SJekt1 fM1bsa"><div class="JiknFv"><svg xmlns="http://www.w3.org/2000/svg" class="rE8OAo" width="16" height="16" viewBox="0 0 20 16"><path d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" class="JX9D2X" stroke="#FFF" fill-rule="evenodd" opacity=".9"></path></svg></div></div></div><div class="ZFwe0M row"><div class="col col-7-12"><div class="t7gRps"><svg width="62" height="18" xmlns="http://www.w3.org/2000/svg" class=""><rect width="62" height="18" fill="white"></rect><path d="M5.82955 6.45455C5.77841 6.02273 5.57102 5.6875 5.20739 5.44886C4.84375 5.21023 4.39773 5.09091 3.86932 5.09091C3.48295 5.09091 3.14489 5.15341 2.85511 5.27841C2.56818 5.40341 2.34375 5.57528 2.18182 5.79403C2.02273 6.01278 1.94318 6.26136 1.94318 6.53977C1.94318 6.77273 1.99858 6.97301 2.10938 7.14062C2.22301 7.3054 2.3679 7.44318 2.54403 7.55398C2.72017 7.66193 2.90483 7.75142 3.09801 7.82244C3.29119 7.89062 3.46875 7.94602 3.63068 7.98864L4.51705 8.22727C4.74432 8.28693 4.99716 8.36932 5.27557 8.47443C5.55682 8.57955
ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/Windows 11 Home) 15ACL6 | 15ALC7 ...</div><div class="a7saXW"><span id="productRating_LSTCOMG9VHHF6HVJPP9U213LU_COMG9VHHF6HVJPP9_" class="CjyrHS"><div class="MKiFS6">4.2<img src="..." class="PZfbSE"></div></span><span class="PvbNMB"><span><span>6,981 Ratings&nbsp;</span><span class="o2SIOJ">&amp;</span><span>&nbsp;569 Reviews</span></span></span></div><div class="CMXw7N"><ul class="HwRTzP"><li class="DTBslk">AMD Ryzen 5 Hexa Core Processor</li><li class="DTBslk">8 GB DDR4 RAM</li><li class="DTBslk">64 bit Windows 11 Operating System</li><li class="DTBslk">512 GB SSD</li><li class="DTBslk">39.62 cm (15.6 inch) Display</li><li class="DTBslk">Office Home and Student 2021</li><li class="DTBslk">1 Year Onsite + 1 Year Accidental Damage Protection</li></ul></div></div><div class="col col-5-12 mao5dl"><div class="oFEPlD"><div class="QiMO5r"><div class="hZ3P6w DeU9vF">₹34,400</div><div class="kRYCnD gxR4EY">₹47,290</div><div class="HQe8jr"><span>27% off</span></div></div></div><div class="qYp2rh"><img height="21" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/fa_9e47c1.png"></div><div class="MaiFhH"><div class="hx1EGN"><div class="HZ0E6r Rm9_cy" style="color: rgb(0, 0, 0); font-size: 14px; font-style: normal; font-weight: 400;">Upto </div><div class="HZ0E6r Rm9_cy" style="color: rgb(0, 0, 0); font-size: 14px; font-style: normal; font-weight: 700;">₹22,000</div><div class="HZ0E6r Rm9_cy" style="color: rgb(0, 0, 0); font-size: 14px; font-style: normal; font-weight: 400;"> Off on Exchange</div></div></div><div class="MaiFhH"><div class="hx1EGN"><div class="HZ0E6r Rm9_cy" style="color: rgb(38, 165, 65); font-size: 14px; font-weight: 700;">Bank Offer</div></div></div></div></div></a></div></div>
# Out:
#   File "C:\Users\Ragasudha\AppData\Local\Temp\ipykernel_24292\3738457559.py", line 1
#     <div data-id="COMG9VHHF6HVJPP9" style="width: 100%;"><div class="jIjQ8S" data-tkid="en_ID-0s5HWpq_SywYaWcPFRfABFcpIldRNEgNCNtDI4PrAT4BffvSlcEwvwgROmXNrn0WVbdNFF5OvNPBl0Ab1-_UFjCTyOHoHZs-Z5_PS_w0="><a class="k7wcnx" target="_blank" rel="noopener noreferrer" href="/lenovo-ideapad-slim-1-amd-ryzen-5-hexa-core-5500u-8-gb-512-gb-ssd-windows-11-home-15acl6-15alc7-2-thin-light-laptop/p/itm3680fb576eb7b?pid=COMG9VHHF6HVJPP9&amp;lid=LSTCOMG9VHHF6HVJPP9U213LU&amp;marketplace=FLIPKART&amp;q=laptop&amp;store=6bo%2Fb5g&amp;srno=s_1_1&amp;otracker=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&amp;otracker1=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&amp;fm=organic&amp;iid=en_ID-0s5HWpq_SywYaWcPFRfABFcpIldRNEgNCNtDI4PrAT4BffvSlcEwvwgROmXNrn0WVbdNFF5OvNPBl0Ab1-_UFjCTyOHoHZs-Z5_PS_w0%3D&amp;ppt=None&amp;ppn=None&amp;ssid=sl6ljjdi6o0000001767327211808&amp;qH=312f91285e048e09"><div class="T6hTMI" data-tkid="ADVIEW_en_ID-0s5HWpq_SywYaWcPFRfABFcpIldRNEgNCNtDI4PrAT4BffvSlcEwvwgROmXNrn0WVbdNFF5OvNPBl0Ab1-_UFjCTyOHoHZs-Z5_PS_w0="><div class="R7Cntx"><div><div class="lWX0_T" style="height: 200px; width: 200px;"><img loading="eager" class="UCc1lI" alt="Lenovo IdeaPad Slim 1 AMD Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/Windows 11 Home) 
HILIPS 126 cm (50 inch) QLED Ultra HD (4K) Smart Google TV 2025 Edition with Dolby Vision 30W Dolby A...</div>

# %%
productname=[]

for x in soup.find_all('div',attrs={'class':'RG5Slk'}):
    productname.append(x.text if x else np.nan)

for name in productname:
    print(name)
# Out:
# PHILIPS 126 cm (50 inch) QLED Ultra HD (4K) Smart Google TV 2025 Edition with Dolby Vision 30W Dolby A...
# PHILIPS 138 cm (55 inch) QLED Ultra HD (4K) Smart Google TV 2025 Edition with Dolby Vision |30W Dolby ...
# Foxsky 60 cm (24 inch) HD Ready LED TV
# XIAOMI 125 cm (50 inch) Ultra HD (4K) LED Smart Google TV with Dolby Vision HDR 10 30W Dolby Audio Xia...
# PHILIPS 164 cm (65 inch) QLED Ultra HD (4K) Smart Google TV 2025 Edition with Dolby Vision |30W Dolby ...
# XIAOMI F Pro 138 cm (55 inch) QLED Ultra HD (4K) Smart Fire TV 2025 Edition with 34W Box Speakers Dolb...
# LG AI TV UA8200 126 cm (50 inch) Ultra HD (4K) LED Smart WebOS TV 2025 Edition with Alpha7 AI Processo...
# XIAOMI Fire Tv 80 cm (32 inch) HD Ready LED Smart Fire TV with High-Definition Display Dolby Surround ...
# Foxsky 60 cm (24 inch) HD Ready LED Smart Android TV 2025 Edition
# realme TechLife 109 cm (43 inch) Ultra HD (4K) LED Smart Google TV 2025 Edition with 5.0 with Dolby Au...
# Coocaa 138 cm (55 inch) Ultra HD (4K) Mini LED Smart Google TV 2025 Edition with Local Dimming - 2025 ...
# realme TechLife 80 cm (32 inch) QLED HD Ready Smart Google TV 2025 Edition
# Thomson Alpha 60 cm (24 Inch) HD Ready LED Smart Linux TV with 20 W Sound Output
# Coocaa S4U Plus 126 cm (50 inch) Full HD LED Smart Coolita TV 2025 Edition with Dolby Audio| Narrow Fr...
# Foxsky 109 cm (43 inch) Full HD LED Smart Android TV
# LG AI TV UA8200 108 cm (43 inch) Ultra HD (4K) LED Smart WebOS TV 2025 Edition with Alpha7 AI Processo...
# realme TechLife 164 cm (65 inch) QLED Ultra HD (4K) Smart Google TV 2025 Edition
# BESTON 189 cm (75 inch) QLED Ultra HD (4K) Smart Google TV 2025 Edition
# MOTOROLA 80 cm (32 inch) QLED HD Ready Smart Google TV 2025 Edition
# XIAOMI A 80 cm (32 inch) HD Ready LED Smart Google TV with 200+ Free Channels HDR 10 Dolby Audio Premi...
# BESTON 140 cm (55 inch) QLED Ultra HD (4K) Smart Google TV 2025 Edition
# Thomson 80 cm (32 inch) HD Ready LED TV 2025 Edition with 20W Sound Output | 2 Speakers | Wide View An...
# MarQ by Flipkart 80 cm (32 inch) HD Ready LED TV
# Infinix 80 cm (32 inch) HD Ready LED Smart Linux TV

# %%
ratings=soup.find("div",attrs={"class":"MKiFS6"})

# %%
ratings
# Out:
# <div class="MKiFS6">4.1<img class="PZfbSE" src="..."/></div>

# %%
ratings=[]

for x in soup.find_all('div',attrs={'class':'MKiFS6'}):
   ratings.append(x.text if x else np.nan)

for name in ratings:
    print(name)
# Out:
# 4.1
# 4.1
# 4
# 4.3
# 4.1
# 4
# 4.4
# 4.3
# 4
# 4.3
# 5
# 4.3
# 4.3
# 4.1
# 4
# 4.4
# 4.3
# 3.9
# 4.3
# 4.3
# 3.9
# 4.1
# 4.2
# 4.2
# 4.3
# 5
# 4
# 4.3
# 5
# 5
# 4.3
# 4
# 5
# 4
# 5
# 5
# 5
# 5
# 5

# %%
for i in range(1,100):
    url=f"https://www.flipkart.com/search?q=television"
    print(url)
# Out:
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television

# %%
from bs4 import BeautifulSoup
import requests
import numpy as np
import time

productname = [] 
price = []
rating = []
features = []
pagenum = []
original_price = []
Discount = []
Review = []

total_time = time.time()

for i in range(1,106): 
    start_time = time.time()
    URL = f"https://www.flipkart.com/search?q=television"
    page = requests.get(URL)
    soup = BeautifulSoup(page.text, "html.parser")

    for x in soup.find_all('div', attrs={'class':'ZFwe0M row'}):
        pname = x.find('div', attrs={'class':'RG5Slk'})
        cost = x.find('div', attrs={'class':'hZ3P6w DeU9vF'})   # discounted price
        rat = x.find('div', attrs={'class':'MKiFS6'})
        specs = x.find('div', attrs={'class':'CMXw7N'})
        op = x.find('div', attrs={'class':'kRYCnD gxR4EY'})
        discount = x.find('div', attrs={'class':'HQe8jr'})
        reviews = x.find('span', attrs={'class':'PvbNMB'})
        

        productname.append(pname.text if pname else np.nan)
        price.append(cost.text if cost else np.nan)
        rating.append(rat.text if rat else np.nan)
        features.append(specs.text if specs else np.nan)
        original_price.append(op.text if op else np.nan)
        Discount.append(discount.text if discount else np.nan)
        Review.append(reviews.text if reviews else np.nan)
        
        pagenum.append(i)

    print(f'Page {i} completed in {time.time()-start_time:.2f} seconds')

print("Total Time Completed in seconds", str(time.time()-total_time))
# Out:
# Page 1 completed in 0.80 seconds
# Page 2 completed in 0.86 seconds
# Page 3 completed in 0.73 seconds
# Page 4 completed in 1.36 seconds
# Page 5 completed in 1.74 seconds
# Page 6 completed in 1.36 seconds
# Page 7 completed in 3.51 seconds
# Page 8 completed in 3.53 seconds
# Page 9 completed in 3.05 seconds
# Page 10 completed in 4.86 seconds
# Page 11 completed in 3.56 seconds
# Page 12 completed in 3.55 seconds
# Page 13 completed in 1.60 seconds
# Page 14 completed in 1.15 seconds
# Page 15 completed in 0.72 seconds
# Page 16 completed in 0.73 seconds
# Page 17 completed in 1.10 seconds
# Page 18 completed in 1.13 seconds
# Page 19 completed in 2.42 seconds
# Page 20 completed in 0.86 seconds
# Page 21 completed in 0.89 seconds
# Page 22 completed in 1.01 seconds
# Page 23 completed in 0.87 seconds
# Page 24 completed in 0.27 seconds
# Page 25 completed in 0.71 seconds
# Page 26 completed in 0.82 seconds
# Page 27 completed in 0.81 seconds
# Page 28 completed in 0.56 seconds
# Page 29 completed in 1.29 seconds
# Page 30 completed in 6.65 seconds
# Page 31 completed in 3.10 seconds
# Page 32 completed in 1.03 seconds
# Page 33 completed in 1.93 seconds
# Page 34 completed in 1.67 seconds
# Page 35 completed in 4.32 seconds
# Page 36 completed in 7.13 seconds
# Page 37 completed in 7.43 seconds
# Page 38 completed in 11.57 seconds
# Page 39 completed in 1.21 seconds
# Page 40 completed in 2.75 seconds
# Page 41 completed in 0.73 seconds
# Page 42 completed in 1.62 seconds
# Page 43 completed in 2.06 seconds
# Page 44 completed in 2.03 seconds
# Page 45 completed in 3.40 seconds
# Page 46 completed in 15.70 seconds
# Page 47 completed in 3.05 seconds
# Page 48 completed in 7.11 seconds
# Page 49 completed in 4.79 seconds
# Page 50 completed in 1.21 seconds
# Page 51 completed in 9.02 seconds
# Page 52 completed in 2.28 seconds
# Page 53 completed in 4.58 seconds
# Page 54 completed in 5.46 seconds
# Page 55 completed in 2.93 seconds
# Page 56 completed in 1.35 seconds
# Page 57 completed in 4.15 seconds
# Page 58 completed in 10.91 seconds
# Page 59 completed in 3.02 seconds
# Page 60 completed in 1.87 seconds
# Page 61 completed in 2.43 seconds
# Page 62 completed in 4.12 seconds
# Page 63 completed in 11.57 seconds
# Page 64 completed in 3.12 seconds
# Page 65 completed in 7.03 seconds
# Page 66 completed in 0.95 seconds
# Page 67 completed in 0.78 seconds
# Page 68 completed in 1.14 seconds
# Page 69 completed in 2.42 seconds
# Page 70 completed in 0.69 seconds
# Page 71 completed in 0.88 seconds
# Page 72 completed in 1.52 seconds
# Page 73 completed in 1.11 seconds
# Page 74 completed in 1.15 seconds
# Page 75 completed in 0.88 seconds
# Page 76 completed in 0.94 seconds
# Page 77 completed in 0.93 seconds
# Page 78 completed in 1.85 seconds
# Page 79 completed in 1.35 seconds
# Page 80 completed in 0.99 seconds
# Page 81 completed in 0.91 seconds
# Page 82 completed in 1.04 seconds
# Page 83 completed in 1.01 seconds
# Page 84 completed in 1.03 seconds
# Page 85 completed in 0.35 seconds
# Page 86 completed in 0.86 seconds
# Page 87 completed in 1.01 seconds
# Page 88 completed in 0.86 seconds
# Page 89 completed in 1.10 seconds
# Page 90 completed in 1.03 seconds
# Page 91 completed in 1.16 seconds
# Page 92 completed in 0.99 seconds
# Page 93 completed in 0.93 seconds
# Page 94 completed in 0.99 seconds
# Page 95 completed in 1.05 seconds
# Page 96 completed in 0.92 seconds
# Page 97 completed in 0.82 seconds
# Page 98 completed in 1.04 seconds
# Page 99 completed in 0.80 seconds
# Page 100 completed in 0.82 seconds
# Page 101 completed in 0.72 seconds
# Page 102 completed in 0.65 seconds
# Page 103 completed in 0.61 seconds
# Page 104 completed in 0.61 seconds
# Page 105 completed in 0.61 seconds
# Total Time Completed in seconds 249.71096777915955

# %%
television_df = pd.DataFrame({
   "productname": productname,
   "productprice": price,
   "product_rating": rating,
   "product_features": features,
   "product_orginal_price":original_price,
   "product_Discount": Discount,
   "product_reviews": Review,
})

# %%
television_df
# Out:
#                                             productname productprice  \
# 0     PHILIPS 126 cm (50 inch) QLED Ultra HD (4K) Sm...      ₹25,999
# 1     PHILIPS 138 cm (55 inch) QLED Ultra HD (4K) Sm...      ₹32,999
# 2                Foxsky 60 cm (24 inch) HD Ready LED TV       ₹4,999
# 3     XIAOMI 125 cm (50 inch) Ultra HD (4K) LED Smar...      ₹28,999
# 4     PHILIPS 164 cm (65 inch) QLED Ultra HD (4K) Sm...      ₹45,999
# ...                                                 ...          ...
# 2419  XIAOMI A 80 cm (32 inch) HD Ready LED Smart Go...      ₹12,499
# 2420   MarQ by Flipkart 80 cm (32 inch) HD Ready LED TV       ₹7,199
# 2421  BESTON 140 cm (55 inch) QLED Ultra HD (4K) Sma...      ₹21,599
# 2422  Infinix 80 cm (32 inch) HD Ready LED Smart Lin...       ₹8,499
# 2423  realme TechLife 140 cm (55 inch) QLED Ultra HD...      ₹27,699
#
#      product_rating                                   product_features  \
# 0               4.1  Ultra HD (4K) | QLEDModel ID: 50PQT8100/94Laun...
# 1               4.1  Ultra HD (4K) | QLEDModel ID: 55PQT8100/94Laun...
# 2                 4  HD Ready | LEDModel ID: 24FSNLaunch Year: 2023...
# 3               4.3  Ultra HD (4K) | LEDModel ID: L50MB-AINLaunch Y...
# 4               4.1  Ultra HD (4K) | QLEDModel ID: 65PQT8100/94Laun...
# ...             ...                                                ...
# 2419            4.3  HD Ready | LEDModel ID: L32MB-AINLaunch Year: ...
# 2420            4.2  HD Ready | LEDModel ID: 32HDNDQEE1BLaunch Year...
# 2421            3.9  Ultra HD (4K) | QLEDModel ID: BS55UGTVLaunch Y...
# 2422            4.2  HD Ready | LEDModel ID: 32Y1D/32Y1C/32Y1BLaunc...
# 2423            4.4  Ultra HD (4K) | QLEDModel ID: 55UHDGQRVSAQLaun...
#
#      product_orginal_price product_Discount                   product_reviews
# 0                  ₹32,999          21% off       1,851 Ratings & 295 Reviews
# 1                  ₹44,999          26% off       1,851 Ratings & 295 Reviews
# 2                  ₹12,999          61% off       5,221 Ratings & 631 Reviews
# 3                  ₹44,999          35% off    82,845 Ratings & 6,132 Reviews
# 4                  ₹54,999          16% off       1,851 Ratings & 295 Reviews
# ...                    ...              ...                               ...
# 2419               ₹24,999          50% off  1,08,889 Ratings & 7,024 Reviews
# 2420               ₹17,000          57% off      10,847 Ratings & 811 Reviews
# 2421               ₹59,999          64% off       1,694 Ratings & 315 Reviews
# 2422               ₹16,999          50% off    65,434 Ratings & 6,149 Reviews
# 2423               ₹65,399          57% off       2,194 Ratings & 247 Reviews
#
# [2424 rows x 7 columns]

# %%
television_df.to_csv("Flipkart_television.csv",index=False)

# %%
df=pd.read_csv("Flipkart_television.csv")

# %%
df
# Out:
#                                             productname productprice  \
# 0     PHILIPS 126 cm (50 inch) QLED Ultra HD (4K) Sm...      ₹25,999
# 1     PHILIPS 138 cm (55 inch) QLED Ultra HD (4K) Sm...      ₹32,999
# 2                Foxsky 60 cm (24 inch) HD Ready LED TV       ₹4,999
# 3     XIAOMI 125 cm (50 inch) Ultra HD (4K) LED Smar...      ₹28,999
# 4     PHILIPS 164 cm (65 inch) QLED Ultra HD (4K) Sm...      ₹45,999
# ...                                                 ...          ...
# 2419  XIAOMI A 80 cm (32 inch) HD Ready LED Smart Go...      ₹12,499
# 2420   MarQ by Flipkart 80 cm (32 inch) HD Ready LED TV       ₹7,199
# 2421  BESTON 140 cm (55 inch) QLED Ultra HD (4K) Sma...      ₹21,599
# 2422  Infinix 80 cm (32 inch) HD Ready LED Smart Lin...       ₹8,499
# 2423  realme TechLife 140 cm (55 inch) QLED Ultra HD...      ₹27,699
#
#       product_rating                                   product_features  \
# 0                4.1  Ultra HD (4K) | QLEDModel ID: 50PQT8100/94Laun...
# 1                4.1  Ultra HD (4K) | QLEDModel ID: 55PQT8100/94Laun...
# 2                4.0  HD Ready | LEDModel ID: 24FSNLaunch Year: 2023...
# 3                4.3  Ultra HD (4K) | LEDModel ID: L50MB-AINLaunch Y...
# 4                4.1  Ultra HD (4K) | QLEDModel ID: 65PQT8100/94Laun...
# ...              ...                                                ...
# 2419             4.3  HD Ready | LEDModel ID: L32MB-AINLaunch Year: ...
# 2420             4.2  HD Ready | LEDModel ID: 32HDNDQEE1BLaunch Year...
# 2421             3.9  Ultra HD (4K) | QLEDModel ID: BS55UGTVLaunch Y...
# 2422             4.2  HD Ready | LEDModel ID: 32Y1D/32Y1C/32Y1BLaunc...
# 2423             4.4  Ultra HD (4K) | QLEDModel ID: 55UHDGQRVSAQLaun...
#
#      product_orginal_price product_Discount                   product_reviews
# 0                  ₹32,999          21% off       1,851 Ratings & 295 Reviews
# 1                  ₹44,999          26% off       1,851 Ratings & 295 Reviews
# 2                  ₹12,999          61% off       5,221 Ratings & 631 Reviews
# 3                  ₹44,999          35% off    82,845 Ratings & 6,132 Reviews
# 4                  ₹54,999          16% off       1,851 Ratings & 295 Reviews
# ...                    ...              ...                               ...
# 2419               ₹24,999          50% off  1,08,889 Ratings & 7,024 Reviews
# 2420               ₹17,000          57% off      10,847 Ratings & 811 Reviews
# 2421               ₹59,999          64% off       1,694 Ratings & 315 Reviews
# 2422               ₹16,999          50% off    65,434 Ratings & 6,149 Reviews
# 2423               ₹65,399          57% off       2,194 Ratings & 247 Reviews
#
# [2424 rows x 7 columns]

# %%
len(name)
len(price)
len(rating)
len(features)
len(pagenum)
len(original_price)
len(Discount)
len(Review)
# Out:
# 2424

# %%
television_df=pd.DataFrame({"product_name":productname,"price":price,"rating":rating,"pagenum":pagenum,
                              "original_price":original_price,"Discount":Discount,"Review":Review})

# %%
television_df
# Out:
#                                            product_name    price rating  \
# 0     PHILIPS 126 cm (50 inch) QLED Ultra HD (4K) Sm...  ₹25,999    4.1
# 1     PHILIPS 138 cm (55 inch) QLED Ultra HD (4K) Sm...  ₹32,999    4.1
# 2                Foxsky 60 cm (24 inch) HD Ready LED TV   ₹4,999      4
# 3     XIAOMI 125 cm (50 inch) Ultra HD (4K) LED Smar...  ₹28,999    4.3
# 4     PHILIPS 164 cm (65 inch) QLED Ultra HD (4K) Sm...  ₹45,999    4.1
# ...                                                 ...      ...    ...
# 2419  XIAOMI A 80 cm (32 inch) HD Ready LED Smart Go...  ₹12,499    4.3
# 2420   MarQ by Flipkart 80 cm (32 inch) HD Ready LED TV   ₹7,199    4.2
# 2421  BESTON 140 cm (55 inch) QLED Ultra HD (4K) Sma...  ₹21,599    3.9
# 2422  Infinix 80 cm (32 inch) HD Ready LED Smart Lin...   ₹8,499    4.2
# 2423  realme TechLife 140 cm (55 inch) QLED Ultra HD...  ₹27,699    4.4
#
#       pagenum original_price Discount                            Review
# 0           1        ₹32,999  21% off       1,851 Ratings & 295 Reviews
# 1           1        ₹44,999  26% off       1,851 Ratings & 295 Reviews
# 2           1        ₹12,999  61% off       5,221 Ratings & 631 Reviews
# 3           1        ₹44,999  35% off    82,845 Ratings & 6,132 Reviews
# 4           1        ₹54,999  16% off       1,851 Ratings & 295 Reviews
# ...       ...            ...      ...                               ...
# 2419      105        ₹24,999  50% off  1,08,889 Ratings & 7,024 Reviews
# 2420      105        ₹17,000  57% off      10,847 Ratings & 811 Reviews
# 2421      105        ₹59,999  64% off       1,694 Ratings & 315 Reviews
# 2422      105        ₹16,999  50% off    65,434 Ratings & 6,149 Reviews
# 2423      105        ₹65,399  57% off       2,194 Ratings & 247 Reviews
#
# [2424 rows x 7 columns]

# %%
television_df.to_csv("television.csv",index=False)

# %%
df=pd.read_csv("television.csv")

# %%
df
# Out:
#                                            product_name    price  rating  \
# 0     PHILIPS 126 cm (50 inch) QLED Ultra HD (4K) Sm...  ₹25,999     4.1
# 1     PHILIPS 138 cm (55 inch) QLED Ultra HD (4K) Sm...  ₹32,999     4.1
# 2                Foxsky 60 cm (24 inch) HD Ready LED TV   ₹4,999     4.0
# 3     XIAOMI 125 cm (50 inch) Ultra HD (4K) LED Smar...  ₹28,999     4.3
# 4     PHILIPS 164 cm (65 inch) QLED Ultra HD (4K) Sm...  ₹45,999     4.1
# ...                                                 ...      ...     ...
# 2419  XIAOMI A 80 cm (32 inch) HD Ready LED Smart Go...  ₹12,499     4.3
# 2420   MarQ by Flipkart 80 cm (32 inch) HD Ready LED TV   ₹7,199     4.2
# 2421  BESTON 140 cm (55 inch) QLED Ultra HD (4K) Sma...  ₹21,599     3.9
# 2422  Infinix 80 cm (32 inch) HD Ready LED Smart Lin...   ₹8,499     4.2
# 2423  realme TechLife 140 cm (55 inch) QLED Ultra HD...  ₹27,699     4.4
#
#       pagenum original_price Discount                            Review
# 0           1        ₹32,999  21% off       1,851 Ratings & 295 Reviews
# 1           1        ₹44,999  26% off       1,851 Ratings & 295 Reviews
# 2           1        ₹12,999  61% off       5,221 Ratings & 631 Reviews
# 3           1        ₹44,999  35% off    82,845 Ratings & 6,132 Reviews
# 4           1        ₹54,999  16% off       1,851 Ratings & 295 Reviews
# ...       ...            ...      ...                               ...
# 2419      105        ₹24,999  50% off  1,08,889 Ratings & 7,024 Reviews
# 2420      105        ₹17,000  57% off      10,847 Ratings & 811 Reviews
# 2421      105        ₹59,999  64% off       1,694 Ratings & 315 Reviews
# 2422      105        ₹16,999  50% off    65,434 Ratings & 6,149 Reviews
# 2423      105        ₹65,399  57% off       2,194 Ratings & 247 Reviews
#
# [2424 rows x 7 columns]

# %%
df.shape
# Out:
# (2424, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2424 entries, 0 to 2423
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_name    2424 non-null   object
#  1   price           2424 non-null   object
#  2   rating          2424 non-null   float64
#  3   pagenum         2424 non-null   int64
#  4   original_price  2424 non-null   object
#  5   Discount        2424 non-null   object
#  6   Review          2424 non-null   object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 132.7+ KB

# %%
df.isnull().sum()
# Out:
# product_name      0
# price             0
# rating            0
# pagenum           0
# original_price    0
# Discount          0
# Review            0
# dtype: int64

# %%
df.head()
# Out:
#                                         product_name    price  rating  \
# 0  PHILIPS 126 cm (50 inch) QLED Ultra HD (4K) Sm...  ₹25,999     4.1
# 1  PHILIPS 138 cm (55 inch) QLED Ultra HD (4K) Sm...  ₹32,999     4.1
# 2             Foxsky 60 cm (24 inch) HD Ready LED TV   ₹4,999     4.0
# 3  XIAOMI 125 cm (50 inch) Ultra HD (4K) LED Smar...  ₹28,999     4.3
# 4  PHILIPS 164 cm (65 inch) QLED Ultra HD (4K) Sm...  ₹45,999     4.1
#
#    pagenum original_price Discount                          Review
# 0        1        ₹32,999  21% off     1,851 Ratings & 295 Reviews
# 1        1        ₹44,999  26% off     1,851 Ratings & 295 Reviews
# 2        1        ₹12,999  61% off     5,221 Ratings & 631 Reviews
# 3        1        ₹44,999  35% off  82,845 Ratings & 6,132 Reviews
# 4        1        ₹54,999  16% off     1,851 Ratings & 295 Reviews

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2424 entries, 0 to 2423
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_name    2424 non-null   object
#  1   price           2424 non-null   object
#  2   rating          2424 non-null   float64
#  3   pagenum         2424 non-null   int64
#  4   original_price  2424 non-null   object
#  5   Discount        2424 non-null   object
#  6   Review          2424 non-null   object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 132.7+ KB

# %%
print(df.isnull().sum())
# Out:
# product_name      0
# price             0
# rating            0
# pagenum           0
# original_price    0
# Discount          0
# Review            0
# dtype: int64

# %%
# df.drop(columns=['features'], inplace=True)

# %%
# Remove non-numeric characters and convert to float
df['Discount'] = df['Discount'].str.extract('(\d+)').astype(float)

df['Review'] = df['Review'].str.replace(',', '').str.extract('(\d+)').astype(float)

# %%
df.isnull().sum()
# Out:
# product_name      0
# price             0
# rating            0
# pagenum           0
# original_price    0
# Discount          0
# Review            0
# dtype: int64

# %%
df["original_price"].value_counts()
# Out:
# ₹24,999      201
# ₹44,999      198
# ₹23,999      102
# ₹86,599      101
# ₹59,999      101
# ₹46,090      101
# ₹41,499      101
# ₹35,999      101
# ₹9,999       101
# ₹40,499      101
# ₹26,999      101
# ₹9,990       101
# ₹64,490      101
# ₹17,000      101
# ₹15,999      100
# ₹12,999      100
# ₹1,14,999    100
# ₹32,999       97
# ₹64,999       97
# ₹54,999       97
# ₹16,999       89
# ₹62,999       52
# ₹89,999       32
# ₹65,399       30
# ₹30,999        4
# ₹57,000        4
# ₹49,990        4
# ₹37,999        4
# ₹22,499        1
# ₹41,300        1
# Name: original_price, dtype: int64

# %%
df["original_price"].fillna(df["original_price"].mode()[0],inplace = True)

# %%
df["Discount"].value_counts()
# Out:
# 50.0    387
# 54.0    200
# 35.0    137
# 57.0    131
# 53.0    105
# 34.0    104
# 37.0    101
# 64.0    101
# 43.0    101
# 44.0    101
# 51.0    101
# 59.0    101
# 56.0    101
# 69.0    101
# 61.0    100
# 21.0     97
# 26.0     97
# 38.0     97
# 16.0     97
# 47.0     56
# 28.0      4
# 66.0      1
# 42.0      1
# 48.0      1
# 31.0      1
# Name: Discount, dtype: int64

# %%
df["Discount"].fillna(df["Discount"].mode()[0],inplace = True)

# %%
df.isnull().sum()
# Out:
# product_name      0
# price             0
# rating            0
# pagenum           0
# original_price    0
# Discount          0
# Review            0
# dtype: int64

# %%
df.head()
# Out:
#                                         product_name    price  rating  \
# 0  PHILIPS 126 cm (50 inch) QLED Ultra HD (4K) Sm...  ₹25,999     4.1
# 1  PHILIPS 138 cm (55 inch) QLED Ultra HD (4K) Sm...  ₹32,999     4.1
# 2             Foxsky 60 cm (24 inch) HD Ready LED TV   ₹4,999     4.0
# 3  XIAOMI 125 cm (50 inch) Ultra HD (4K) LED Smar...  ₹28,999     4.3
# 4  PHILIPS 164 cm (65 inch) QLED Ultra HD (4K) Sm...  ₹45,999     4.1
#
#    pagenum original_price  Discount   Review
# 0        1        ₹32,999      21.0   1851.0
# 1        1        ₹44,999      26.0   1851.0
# 2        1        ₹12,999      61.0   5221.0
# 3        1        ₹44,999      35.0  82845.0
# 4        1        ₹54,999      16.0   1851.0

# %%
null=df[df['price'].isnull()].index

# %%
df[df['price'].isnull()].index
# Out:
# Int64Index([], dtype='int64')

# %%
df['price'].fillna(14000, inplace=True)

# %%
df.isnull().sum()
# Out:
# product_name      0
# price             0
# rating            0
# pagenum           0
# original_price    0
# Discount          0
# Review            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['product_name']
# Out:
# 0       PHILIPS 126 cm (50 inch) QLED Ultra HD (4K) Sm...
# 1       PHILIPS 138 cm (55 inch) QLED Ultra HD (4K) Sm...
# 2                  Foxsky 60 cm (24 inch) HD Ready LED TV
# 3       XIAOMI 125 cm (50 inch) Ultra HD (4K) LED Smar...
# 4       PHILIPS 164 cm (65 inch) QLED Ultra HD (4K) Sm...
#                               ...
# 2419    XIAOMI A 80 cm (32 inch) HD Ready LED Smart Go...
# 2420     MarQ by Flipkart 80 cm (32 inch) HD Ready LED TV
# 2421    BESTON 140 cm (55 inch) QLED Ultra HD (4K) Sma...
# 2422    Infinix 80 cm (32 inch) HD Ready LED Smart Lin...
# 2423    realme TechLife 140 cm (55 inch) QLED Ultra HD...
# Name: product_name, Length: 2424, dtype: object

# %%
import re
df["Brand"]=df["product_name"].apply(lambda x:re.findall(r"^\w+",x)[0])

# %%
df["product_name"].apply(lambda x:re.findall(r"^\w+",x)[0])
# Out:
# 0       PHILIPS
# 1       PHILIPS
# 2        Foxsky
# 3        XIAOMI
# 4       PHILIPS
#          ...
# 2419     XIAOMI
# 2420       MarQ
# 2421     BESTON
# 2422    Infinix
# 2423     realme
# Name: product_name, Length: 2424, dtype: object

# %%
df["Brand"]
# Out:
# 0       PHILIPS
# 1       PHILIPS
# 2        Foxsky
# 3        XIAOMI
# 4       PHILIPS
#          ...
# 2419     XIAOMI
# 2420       MarQ
# 2421     BESTON
# 2422    Infinix
# 2423     realme
# Name: Brand, Length: 2424, dtype: object

# %%
df["Brand"].value_counts().head()
# Out:
# XIAOMI     394
# realme     333
# Foxsky     303
# PHILIPS    291
# LG         206
# Name: Brand, dtype: int64

# %%
df['screen_size_inch']=df["product_name"].apply(lambda x:re.findall(r"\d+",x)[0])

# %%
 df['product_name'].apply(lambda x: re.findall(r"\b\d+\s*L\b", x)[0] if re.findall(r"\b\d+\s*L\b", x) else None)
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 2419    None
# 2420    None
# 2421    None
# 2422    None
# 2423    None
# Name: product_name, Length: 2424, dtype: object

# %%
df["product_name"].apply(lambda x:re.findall(r"\d+",x)[0])
# Out:
# 0       126
# 1       138
# 2        60
# 3       125
# 4       164
#        ...
# 2419     80
# 2420     80
# 2421    140
# 2422     80
# 2423    140
# Name: product_name, Length: 2424, dtype: object

# %%
df['screen_size_inch']=df["product_name"].apply(lambda x:re.findall(r"\d+",x)[0])

# %%
df
# Out:
#                                            product_name    price  rating  \
# 0     PHILIPS 126 cm (50 inch) QLED Ultra HD (4K) Sm...  ₹25,999     4.1
# 1     PHILIPS 138 cm (55 inch) QLED Ultra HD (4K) Sm...  ₹32,999     4.1
# 2                Foxsky 60 cm (24 inch) HD Ready LED TV   ₹4,999     4.0
# 3     XIAOMI 125 cm (50 inch) Ultra HD (4K) LED Smar...  ₹28,999     4.3
# 4     PHILIPS 164 cm (65 inch) QLED Ultra HD (4K) Sm...  ₹45,999     4.1
# ...                                                 ...      ...     ...
# 2419  XIAOMI A 80 cm (32 inch) HD Ready LED Smart Go...  ₹12,499     4.3
# 2420   MarQ by Flipkart 80 cm (32 inch) HD Ready LED TV   ₹7,199     4.2
# 2421  BESTON 140 cm (55 inch) QLED Ultra HD (4K) Sma...  ₹21,599     3.9
# 2422  Infinix 80 cm (32 inch) HD Ready LED Smart Lin...   ₹8,499     4.2
# 2423  realme TechLife 140 cm (55 inch) QLED Ultra HD...  ₹27,699     4.4
#
#       pagenum original_price  Discount    Review    Brand screen_size_inch
# 0           1        ₹32,999      21.0    1851.0  PHILIPS              126
# 1           1        ₹44,999      26.0    1851.0  PHILIPS              138
# 2           1        ₹12,999      61.0    5221.0   Foxsky               60
# 3           1        ₹44,999      35.0   82845.0   XIAOMI              125
# 4           1        ₹54,999      16.0    1851.0  PHILIPS              164
# ...       ...            ...       ...       ...      ...              ...
# 2419      105        ₹24,999      50.0  108889.0   XIAOMI               80
# 2420      105        ₹17,000      57.0   10847.0     MarQ               80
# 2421      105        ₹59,999      64.0    1694.0   BESTON              140
# 2422      105        ₹16,999      50.0   65434.0  Infinix               80
# 2423      105        ₹65,399      57.0    2194.0   realme              140
#
# [2424 rows x 9 columns]

# %%
df["price"] = df["price"].astype(str).apply(lambda x: x[1:] if x.startswith("₹") else x)

# %%
df["price"]
# Out:
# 0       25,999
# 1       32,999
# 2        4,999
# 3       28,999
# 4       45,999
#          ...
# 2419    12,499
# 2420     7,199
# 2421    21,599
# 2422     8,499
# 2423    27,699
# Name: price, Length: 2424, dtype: object

# %%
df["price"]=df["price"].apply(lambda x:re.sub(r",","",x))

# %%
df["price"]
# Out:
# 0       25999
# 1       32999
# 2        4999
# 3       28999
# 4       45999
#         ...
# 2419    12499
# 2420     7199
# 2421    21599
# 2422     8499
# 2423    27699
# Name: price, Length: 2424, dtype: object

# %%
df["price"]=df["price"].astype("int")

# %%
df["original_price"]
# Out:
# 0       ₹32,999
# 1       ₹44,999
# 2       ₹12,999
# 3       ₹44,999
# 4       ₹54,999
#          ...
# 2419    ₹24,999
# 2420    ₹17,000
# 2421    ₹59,999
# 2422    ₹16,999
# 2423    ₹65,399
# Name: original_price, Length: 2424, dtype: object

# %%
df["original_price"].apply(lambda x:x[1:])
# Out:
# 0       32,999
# 1       44,999
# 2       12,999
# 3       44,999
# 4       54,999
#          ...
# 2419    24,999
# 2420    17,000
# 2421    59,999
# 2422    16,999
# 2423    65,399
# Name: original_price, Length: 2424, dtype: object

# %%
df["original_price"]=df["original_price"].apply(lambda x:x[1:])

# %%
df["original_price"]=df["original_price"].apply(lambda x:re.sub(r",","",x))

# %%
df["original_price"]=df["original_price"].astype("int")

# %%
df.dtypes
# Out:
# product_name           object
# price                   int32
# rating                float64
# pagenum                 int64
# original_price          int32
# Discount              float64
# Review                float64
# Brand                  object
# capacity_liters        object
# capacity_in_liters     object
# screen_size_inch       object
# dtype: object

# %%
df.drop(columns=['capacity_in_liters'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24292\4126879081.py in <module>
# ----> 1 df.drop(columns=['capacity_in_liters'], inplace=True)
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['capacity_in_liters'] not found in axis"

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   product_name        0 non-null      object
#  1   price               0 non-null      int32
#  2   rating              0 non-null      float64
#  3   pagenum             0 non-null      int64
#  4   original_price      0 non-null      int32
#  5   Discount            0 non-null      float64
#  6   Review              0 non-null      float64
#  7   Brand               0 non-null      object
#  8   capacity_liters     0 non-null      object
#  9   capacity_in_liters  0 non-null      object
#  10  screen_size_inch    0 non-null      object
# dtypes: float64(3), int32(2), int64(1), object(5)
# memory usage: 0.0+ bytes

# %%
df['product_name'].head(10)
# Out:
# 0    PHILIPS 126 cm (50 inch) QLED Ultra HD (4K) Sm...
# 1    PHILIPS 138 cm (55 inch) QLED Ultra HD (4K) Sm...
# 2               Foxsky 60 cm (24 inch) HD Ready LED TV
# 3    XIAOMI 125 cm (50 inch) Ultra HD (4K) LED Smar...
# 4    PHILIPS 164 cm (65 inch) QLED Ultra HD (4K) Sm...
# 5    XIAOMI F Pro 138 cm (55 inch) QLED Ultra HD (4...
# 6    LG AI TV UA8200 126 cm (50 inch) Ultra HD (4K)...
# 7    XIAOMI Fire Tv 80 cm (32 inch) HD Ready LED Sm...
# 8    Foxsky 60 cm (24 inch) HD Ready LED Smart Andr...
# 9    realme TechLife 109 cm (43 inch) Ultra HD (4K)...
# Name: product_name, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2424 entries, 0 to 2423
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   product_name      2424 non-null   object
#  1   price             2424 non-null   int32
#  2   rating            2424 non-null   float64
#  3   pagenum           2424 non-null   int64
#  4   original_price    2424 non-null   int32
#  5   Discount          2424 non-null   float64
#  6   Review            2424 non-null   float64
#  7   Brand             2424 non-null   object
#  8   screen_size_inch  2424 non-null   object
# dtypes: float64(3), int32(2), int64(1), object(3)
# memory usage: 170.4+ KB

# %%
df.shape
# Out:
# (2424, 9)

# %%
df
# Out:
#                                            product_name  price  rating  \
# 0     PHILIPS 126 cm (50 inch) QLED Ultra HD (4K) Sm...  25999     4.1
# 1     PHILIPS 138 cm (55 inch) QLED Ultra HD (4K) Sm...  32999     4.1
# 2                Foxsky 60 cm (24 inch) HD Ready LED TV   4999     4.0
# 3     XIAOMI 125 cm (50 inch) Ultra HD (4K) LED Smar...  28999     4.3
# 4     PHILIPS 164 cm (65 inch) QLED Ultra HD (4K) Sm...  45999     4.1
# ...                                                 ...    ...     ...
# 2419  XIAOMI A 80 cm (32 inch) HD Ready LED Smart Go...  12499     4.3
# 2420   MarQ by Flipkart 80 cm (32 inch) HD Ready LED TV   7199     4.2
# 2421  BESTON 140 cm (55 inch) QLED Ultra HD (4K) Sma...  21599     3.9
# 2422  Infinix 80 cm (32 inch) HD Ready LED Smart Lin...   8499     4.2
# 2423  realme TechLife 140 cm (55 inch) QLED Ultra HD...  27699     4.4
#
#       pagenum  original_price  Discount    Review    Brand screen_size_inch
# 0           1           32999      21.0    1851.0  PHILIPS              126
# 1           1           44999      26.0    1851.0  PHILIPS              138
# 2           1           12999      61.0    5221.0   Foxsky               60
# 3           1           44999      35.0   82845.0   XIAOMI              125
# 4           1           54999      16.0    1851.0  PHILIPS              164
# ...       ...             ...       ...       ...      ...              ...
# 2419      105           24999      50.0  108889.0   XIAOMI               80
# 2420      105           17000      57.0   10847.0     MarQ               80
# 2421      105           59999      64.0    1694.0   BESTON              140
# 2422      105           16999      50.0   65434.0  Infinix               80
# 2423      105           65399      57.0    2194.0   realme              140
#
# [2424 rows x 9 columns]

# %%
df.to_csv("cleaned_television.csv",index = False)

# %%
df = pd.read_csv("cleaned_television.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2424 entries, 0 to 2423
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   product_name      2424 non-null   object
#  1   price             2424 non-null   int64
#  2   rating            2424 non-null   float64
#  3   pagenum           2424 non-null   int64
#  4   original_price    2424 non-null   int64
#  5   Discount          2424 non-null   float64
#  6   Review            2424 non-null   float64
#  7   Brand             2424 non-null   object
#  8   screen_size_inch  2424 non-null   int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 170.6+ KB

# %%
df.shape
# Out:
# (2424, 9)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
brand_price = df.groupby("Brand")["price"].mean().sort_values(ascending=False)
print(brand_price)
# Out:
# Brand
# Samsung     38090.000000
# BESTON      36602.217822
# PHILIPS     34999.000000
# LG          33089.684466
# Coocaa      28776.777778
# realme      23725.726727
# XIAOMI      23324.629442
# MOTOROLA    10999.000000
# Infinix      8521.471910
# Foxsky       7673.917492
# MarQ         7199.000000
# Thomson      6796.512438
# Name: price, dtype: float64

# %%
brand_rating = df.groupby("Brand")["rating"].mean().sort_values(ascending=False)
print(brand_rating)
# Out:
# Brand
# Coocaa      4.540909
# LG          4.400000
# realme      4.309009
# MOTOROLA    4.300000
# Samsung     4.300000
# XIAOMI      4.236041
# Thomson     4.200498
# MarQ        4.200000
# Infinix     4.177528
# PHILIPS     4.100000
# Foxsky      4.000000
# BESTON      3.899505
# Name: rating, dtype: float64

# %%
brand_discount = df.groupby("Brand")["Discount"].mean().sort_values(ascending=False)
print(brand_discount)
# Out:
# Brand
# MOTOROLA    59.000000
# BESTON      58.970297
# Foxsky      58.016502
# MarQ        57.000000
# realme      53.663664
# Infinix     49.865169
# Thomson     45.457711
# XIAOMI      44.246193
# Coocaa      44.121212
# LG          38.781553
# Samsung     28.600000
# PHILIPS     21.000000
# Name: Discount, dtype: float64

# %%
corr_rating_reviews = df[['rating', 'Review']].corr()
print(corr_rating_reviews)
# Out:
#           rating    Review
# rating  1.000000  0.203602
# Review  0.203602  1.000000

# %%
df_20k_50k = df[(df["price"] >= 20000) & (df["price"] <= 60000)]
df_20k_50k.head()
# Out:
#                                         product_name  price  rating  pagenum  \
# 0  PHILIPS 126 cm (50 inch) QLED Ultra HD (4K) Sm...  25999     4.1        1
# 1  PHILIPS 138 cm (55 inch) QLED Ultra HD (4K) Sm...  32999     4.1        1
# 3  XIAOMI 125 cm (50 inch) Ultra HD (4K) LED Smar...  28999     4.3        1
# 4  PHILIPS 164 cm (65 inch) QLED Ultra HD (4K) Sm...  45999     4.1        1
# 5  XIAOMI F Pro 138 cm (55 inch) QLED Ultra HD (4...  32999     4.0        1
#
#    original_price  Discount   Review    Brand  screen_size_inch
# 0           32999      21.0   1851.0  PHILIPS               126
# 1           44999      26.0   1851.0  PHILIPS               138
# 3           44999      35.0  82845.0   XIAOMI               125
# 4           54999      16.0   1851.0  PHILIPS               164
# 5           62999      47.0  14107.0   XIAOMI               138

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# Bar Chart for Brand (Categorical)

df.columns = df.columns.str.strip()

counts = df["Brand"].value_counts().head(10)
plt.figure(figsize=(6, 4))
plt.bar(counts.index, counts.values, color='green', edgecolor='black')
plt.title("Top 10 Television Brands on Flipkart")
plt.xlabel("Brand")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show();

# %%
# Histogram for Price (Numerical)

plt.figure(figsize=(6, 4))
plt.hist(df['price'], bins=30, color='lightcoral', edgecolor='black')
plt.title("Distribution of Price")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show();

# %%
# Box Plot for Ratings(Numerical) 

plt.figure(figsize=(6, 4))
sns.boxplot(x=df['rating'], color='yellow')

plt.title("Box Plot of Ratings")
plt.xlabel("Rating")
plt.grid(False)
plt.show();

# %%
# Numerical vs. Numerical: Scatter Plot

df.columns = df.columns.str.strip()

plt.figure(figsize=(6, 4))
sns.scatterplot(data=df, x='price', y='rating', color='red', alpha=0.6)

plt.title("Price vs. Rating")
plt.xlabel("Price")
plt.ylabel("Rating")
plt.show();

# %%
# Categorical vs. Numerical: Bar Plot
df.columns = df.columns.str.strip()

plt.figure(figsize=(6, 4))
avg_price_brand = df.groupby('Brand')['price'].mean().sort_values(ascending=False).head(10)
plt.bar(avg_price_brand.index, avg_price_brand.values, color='blue', edgecolor='black')
plt.title("Average Price by Top 10 Brands")
plt.xlabel("Brand")
plt.ylabel("Price")
plt.xticks(rotation=45)
plt.show();

# %%
# Categorical vs. Numerical: Box Plot

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6, 4))

top_5_brands = df['Brand'].value_counts().nlargest(5).index
df_subset = df[df['Brand'].isin(top_5_brands)]

sns.boxplot(data=df_subset, x='Brand', y='price', palette='Set2')

plt.title("Price Distribution by Top 5 Brands")
plt.xlabel("Brand")
plt.ylabel("Price")
plt.grid(False)

plt.show();

# %%
# Numerical vs. Numerical : Heat map

df.columns = df.columns.str.strip()
numeric_cols = ['price','rating','original_price','Discount','Review','screen_size_inch']
correlation_matrix = df[numeric_cols].corr()

plt.figure(figsize=(6, 4))
sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm',center=0,fmt=".2f")
plt.title('Correlation Matrix of television Features')
plt.show();

# %%
# Multivariate Scatter Plot
df.columns = df.columns.str.strip()

plt.figure(figsize=(6, 4))
sns.scatterplot(data=df, x='price', y='rating', hue='Brand', size='Discount', alpha=0.7)
plt.title("Price vs Rating by Brand & Discount")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left') 
plt.show();
